# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pylab import mpl
#mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']    # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False           # 解决保存图像是负号'-'显示为方块的问题


def load_data():
    df_train=pd.read_excel('order_is_cash_2_hz.xlsx')
#     df_train.drop(['Unnamed: 0'],inplace=True,axis=1)
    return df_train

print('读取原始样本数据')
df_train=load_data()
print('打印样本数据')

# %%
df_train.drop(['商户号','总笔数','总金额'],axis=1,inplace=True)
df_train.head()

# %%
print(df_train.shape)
df_train.info()

# %%
x1=df_train['客单价']
x2=df_train['用户数']
x3=df_train["总笔数/用户数"]
x4=df_train["总金额/用户数"]

x5=df_train["近12月有交易的月数"]

x6=df_train["近1月交易天数"]
x7=df_train["近3月交易天数"]
x8=df_train["近6月交易天数"]
x9=df_train["近12月交易天数"]

x10=df_train["近1月交易笔数"]
x11=df_train["近3月交易笔数"]
x12=df_train["近6月交易笔数"]
x13=df_train["近12月交易笔数"]

x14=df_train["近1月交易总金额"]
x15=df_train["近3月交易总金额"]
x16=df_train["近6月交易总金额"]
x17=df_train["近12月交易总金额"]

x18=df_train["近1月22:00~04:00的交易总笔数"]
x19=df_train["近3月22:00~04:00的交易总笔数"]
x20=df_train["近6月22:00~04:00的交易总笔数"]
x21=df_train["近12月22:00~04:00的交易总笔数"]

x22=df_train["近1月22:00~04:00的交易总金额"]
x23=df_train["近3月22:00~04:00的交易总金额"]
x24=df_train["近6月22:00~04:00的交易总金额"]
x25=df_train["近12月22:00~04:00的交易总金额"]


# fig=plt.figure(figsize=(20,500))

ax1=fig.add_subplot(13,2,1)
ax2=fig.add_subplot(13,2,2)
ax3=fig.add_subplot(13,2,3)
ax4=fig.add_subplot(13,2,4)
ax5=fig.add_subplot(13,2,5)
ax6=fig.add_subplot(13,2,6)
ax7=fig.add_subplot(13,2,7)
ax8=fig.add_subplot(13,2,8)
ax9=fig.add_subplot(13,2,9)
ax10=fig.add_subplot(13,2,10)
ax11=fig.add_subplot(13,2,11)
ax12=fig.add_subplot(13,2,12)
ax13=fig.add_subplot(13,2,13)
ax14=fig.add_subplot(13,2,14)
ax15=fig.add_subplot(13,2,15)
ax16=fig.add_subplot(13,2,16)
ax17=fig.add_subplot(13,2,17)
ax18=fig.add_subplot(13,2,18)
ax19=fig.add_subplot(13,2,19)
ax20=fig.add_subplot(13,2,20)
ax21=fig.add_subplot(13,2,21)
ax22=fig.add_subplot(13,2,22)
ax23=fig.add_subplot(13,2,23)
ax24=fig.add_subplot(13,2,24)
ax25=fig.add_subplot(13,2,25)

fontsize=20

df_train[["近12月有交易的月数"]].boxplot(return_type='dict')
# ax1.boxplot(x1)
# ax1.set_xticklabels("客单价", fontsize=fontsize)

# ax2.boxplot(x2)
# ax2.set_xticklabels('用户数', fontsize=fontsize)

# ax3.boxplot(x3)
# ax3.set_xticklabels('总笔数/用户数', fontsize=fontsize)

# ax4.boxplot(x4)
# ax4.set_xticklabels('总金额/用户数', fontsize=fontsize)

# ax8.boxplot([x2,x3])
# ax8.set_xticklabels(["客单价","用户数","总笔数/用户数"], fontsize=fontsize)

# ax2.boxplot(x5)
# ax2.set_xticklabels("近12月有交易的月数", fontsize=fontsize)

# ax3.boxplot([x6,x7,x8,x9])
# ax3.set_xticklabels(["近1月交易天数","近3月交易天数","近6月交易天数","近12月交易天数"], fontsize=fontsize)

# ax4.boxplot([x10,x11,x12,x13])
# ax4.set_xticklabels(["近1月交易笔数","近3月交易笔数","近6月交易笔数","近12月交易笔数"], fontsize=fontsize)

# ax5.boxplot([x14,x15,x16,x17])
# ax5.set_xticklabels(["近1月交易总金额","近3月交易总金额","近6月交易总金额","近12月交易总金额"], fontsize=fontsize)

# ax6.boxplot([x18,x19,x20,x21])
# ax6.set_xticklabels(["近1月22:00~04:00的交易总笔数","近3月22:00~04:00的交易总笔数","近6月22:00~04:00的交易总笔数","近12月22:00~04:00的交易总笔数"], fontsize=fontsize)

# ax7.boxplot([x22,x23,x24,x25])
# ax7.set_xticklabels(["近1月22:00~04:00的交易总金额","近3月22:00~04:00的交易总金额","近6月22:00~04:00的交易总金额","近12月22:00~04:00的交易总金额"], fontsize=fontsize)
# Out:
# e:\program files\python37\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# e:\program files\python37\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
df_train=df_train[df_train['客单价']<20000]
df_train=df_train[df_train['用户数']<1]
df_train=df_train[df_train['总笔数/用户数']<1]
df_train=df_train[df_train['总金额/用户数']<1]

df_train=df_train[df_train['近12月有交易的月数']<1]

df_train=df_train[df_train['近1月交易天数']<1]
df_train=df_train[df_train['近3月交易天数']<1]
df_train=df_train[df_train['近6月交易天数']<1]
df_train=df_train[df_train['近12月交易天数']<1]

df_train=df_train[df_train['近1月交易笔数']<1]
df_train=df_train[df_train['近3月交易笔数']<1]
df_train=df_train[df_train['近6月交易笔数']<1]
df_train=df_train[df_train['近12月交易笔数']<1]

df_train=df_train[df_train['近1月交易总金额']<1]
df_train=df_train[df_train['近3月交易总金额']<1]
df_train=df_train[df_train['近6月交易总金额']<1]
df_train=df_train[df_train['近12月交易总金额']<1]

df_train=df_train[df_train['近1月22:00~04:00的交易总笔数']<1]
df_train=df_train[df_train['近3月22:00~04:00的交易总笔数']<1]
df_train=df_train[df_train['近6月22:00~04:00的交易总笔数']<1]
df_train=df_train[df_train['近12月22:00~04:00的交易总笔数']<1]

df_train=df_train[df_train['近1月22:00~04:00的交易总金额']<1]
df_train=df_train[df_train['近3月22:00~04:00的交易总金额']<1]
df_train=df_train[df_train['近6月22:00~04:00的交易总金额']<1]
df_train=df_train[df_train['近12月22:00~04:00的交易总金额']<1]
